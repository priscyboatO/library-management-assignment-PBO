# %% [markdown]
# <a href="https://colab.research.google.com/github/priscyboatO/library-management-assignment-PBO/blob/main/Lesson_3_assignment_Library__Management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### **ATTENTION!!!**
# - **Place each section (1,2...) in one or more cells to keep the notebook organised**
# - **Complete the codes in the `TODO` sections**

# %% [markdown]
# Import libraries

# %%
# Python Library Management System

# Install required libraries (This should already exist in colab)
# !pip install requests

import pickle
import sqlite3
import requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests) (2026.7.22)

# %% [markdown]
# Task 1: Data types and variables

# %%
# 1. Data Types and Variables
book_title = "Python Programming"
book_quantity = 5
book_price = 29.99
is_available = True

print(f"Book: {book_title}, Quantity: {book_quantity}, Price: ${book_price}, Available: {is_available}")
# Out:
# Book: Python Programming, Quantity: 5, Price: $29.99, Available: True

# %% [markdown]
# Task 2: Lists

# %%
# 2. Lists
books = ["Python Basics", "Advanced Python", "Data Science with Python"]

# Add two more books to the list
books.append("Machine Learning")
books.insert(1, "Artificial Intelligence")

print("Updated book list:", books)
# Out:
# Updated book list: ['Python Basics', 'Artificial Intelligence', 'Advanced Python', 'Data Science with Python', 'Machine Learning']

# %% [markdown]
# Task 3: Loops and range

# %%
# 3. Loops and range()
print("\nAvailable books:")

for i in range(len(books)):
    print(i, books[i])
# Out:
# Available books:
# 0 Python Basics
# 1 Advanced Python
# 2 Data Science with Python

# %% [markdown]
# Task 4: User Input

# %%
# 4. User Input
new_book = input("Enter a new book title: ")
books.append(new_book)
print("Updated book list:", books)
# Out:
# Enter a new book title: Deep Learning
# Updated book list: ['Python Basics', 'Artificial Intelligence', 'Advanced Python', 'Data Science with Python', 'Machine Learning', 'Deep Learning']

# %% [markdown]
# Task 5: Functions and Conditional Statements

# %%
# 5. Functions and Conditional Statements
def check_availability(book_name):
    # Check if the book is in the list
    if book_name in books:
        return True
    else:
        return False

# Test the function
print(f"Is 'Python Basics' available? {check_availability('Python Basics')}")
# Out:
# Is 'Python Basics' available? True

# %% [markdown]
# Task 6: File I/O

# %%
# 6. File I/O
def save_books_to_file(filename):
    with open(filename, 'w') as f:
        for book in books:
            f.write(f"{book}\n")

# Read books from a file
def read_books_from_file(filename):
    try:
        with open(filename, 'r') as f:
            return [line.strip() for line in f]
    except FileNotFoundError:
        return "File not found."

# Test file I/O
save_books_to_file("books.txt")
print("Books read from file:", read_books_from_file("books.txt"))
# Out:
# Books read from file: ['Python Basics', 'Artificial Intelligence', 'Advanced Python', 'Data Science with Python', 'Machine Learning', 'Deep Learning']

# %% [markdown]
# task 7: Pickle for Serialization

# %%
# 7. Pickle for Serialization
def save_books_pickle(filename):
    with open(filename, 'wb') as f:
        pickle.dump(books, f)

# Load books using Pickle
def load_books_pickle(filename):
    try:
        with open(filename, 'rb') as f:
            return pickle.load(f)
    except FileNotFoundError:
        return "File not found."

# Test pickle functions
save_books_pickle("books.pkl")
print("Books loaded from pickle:", load_books_pickle("books.pkl"))
# Out:
# Books loaded from pickle: ['Python Basics', 'Artificial Intelligence', 'Advanced Python', 'Data Science with Python', 'Machine Learning', 'Deep Learning']

# %% [markdown]
# Task 8: SQLite Database Interaction

# %%
# 8. SQLite Database Interaction
def create_books_table():
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute('''CREATE TABLE IF NOT EXISTS books
                      (id INTEGER PRIMARY KEY, title TEXT, quantity INTEGER)''')
    conn.commit()
    conn.close()

# Add a book to the SQLite database
def add_book_to_db(title, quantity):
    try:
        conn = sqlite3.connect('library.db')
        cursor = conn.cursor()
        cursor.execute(
            "INSERT INTO books (title, quantity) VALUES (?, ?)",
            (title, quantity)
        )
        conn.commit()
        conn.close()
        print("Book added successfully.")
    except sqlite3.Error as e:
        print("Database error:", e)

# Test database functions
create_books_table()
add_book_to_db("Python for Beginners", 10)
# Out:
# Book added successfully.

# %% [markdown]
# Task 9: Web API Interaction

# %%
# 9. Web API Interaction (GitHub API)
def get_python_repos():
    url = "https://api.github.com/search/repositories"
    params = {"q": "language:python", "sort": "stars", "order": "desc"}

    response = requests.get(url, params=params)
    data = response.json()

    return [repo['name'] for repo in data['items'][:5]]

# Test API function
print("Top 5 Python repositories on GitHub:", get_python_repos())

print("\nLibrary Management System operations completed.")
# Out:
# Top 5 Python repositories on GitHub: ['public-apis', 'free-programming-books', 'system-design-primer', 'awesome-python', 'project-based-learning']
#
# Library Management System operations completed.
